# %%
print("OK")
# Out:
# OK

# %%
import pandas as pd

# %%
df = pd.read_csv("luxottica_clv_multiclass_dataset.csv")
df.head()
# Out:
#   CustomerID  Age  Gender Income_Level     Eyewear_Type          Brand  \
# 0  CUST00001   56  Female         High       Sunglasses  Vogue Eyewear
# 1  CUST00002   69    Male       Medium  Optical Glasses  Vogue Eyewear
# 2  CUST00003   46    Male       Medium  Optical Glasses        Ray-Ban
# 3  CUST00004   32  Female          Low  Optical Glasses        Ray-Ban
# 4  CUST00005   60    Male       Medium  Optical Glasses         Persol
#
#      Price  Purchase_Frequency  Customer_Tenure_Days  Customer_Satisfaction  \
# 0  1170.99                   1                  1801                   0.62
# 1  1033.90                   2                   913                   0.87
# 2  1284.68                   3                   497                   0.78
# 3  1316.68                   4                   524                   0.63
# 4  1038.45                   5                  1574                   0.53
#
#         CLV CLV_Class
# 0   3582.33       Low
# 1   4499.93    Medium
# 2   4093.31    Medium
# 3   4763.42    Medium
# 4  11867.07      High

# %%
df.shape
# Out:
# (10000, 12)

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'CustomerID': 'CUST00001',
#   'Age': 56,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1170.99,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1801,
#   'Customer_Satisfaction': 0.62,
#   'CLV': 3582.33,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00002',
#   'Age': 69,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1033.9,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 913,
#   'Customer_Satisfaction': 0.87,
#   'CLV': 4499.93,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00003',
#   'Age': 46,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1284.68,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 497,
#   'Customer_Satisfaction': 0.78,
#   'CLV': 4093.31,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00004',
#   'Age': 32,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1316.68,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 524,
#   'Customer_Satisfaction': 0.63,
#   'CLV': 4763.42,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00005',
#   'Age': 60,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1038.45,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1574,
#   'Customer_Satisfaction': 0.53,
#   'CLV': 11867.07,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00006',
#   'Age': 25,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1143.83,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1916,
#   'Customer_Satisfaction': 0.6,
#   'CLV': 7205.19,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00007',
#   'Age': 38,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1129.19,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1017,
#   'Customer_Satisfaction': 0.83,
#   'CLV': 10445.6,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00008',
#   'Age': 56,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 973.74,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1171,
#   'Customer_Satisfaction': 0.78,
#   'CLV': 4873.4,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00009',
#   'Age': 36,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1194.54,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1859,
#   'Customer_Satisfaction': 0.53,
#   'CLV': 16122.53,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00010',
#   'Age': 40,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1028.21,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1442,
#   'Customer_Satisfaction': 0.78,
#   'CLV': 9505.39,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00011',
#   'Age': 28,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1223.85,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1666,
#   'Customer_Satisfaction': 0.7,
#   'CLV': 7820.57,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00012',
#   'Age': 28,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1240.37,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1990,
#   'Customer_Satisfaction': 0.51,
#   'CLV': 13795.63,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00013',
#   'Age': 41,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1258.95,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1471,
#   'Customer_Satisfaction': 0.95,
#   'CLV': 19280.22,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00014',
#   'Age': 53,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1266.2,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 231,
#   'Customer_Satisfaction': 0.63,
#   'CLV': 2524.25,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00015',
#   'Age': 57,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1429.64,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 893,
#   'Customer_Satisfaction': 0.78,
#   'CLV': 2728.22,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00016',
#   'Age': 41,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1078.7,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1922,
#   'Customer_Satisfaction': 0.79,
#   'CLV': 22436.66,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00017',
#   'Age': 20,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1086.23,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 988,
#   'Customer_Satisfaction': 0.75,
#   'CLV': 11025.98,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00018',
#   'Age': 39,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1298.27,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1198,
#   'Customer_Satisfaction': 0.62,
#   'CLV': 2641.93,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00019',
#   'Age': 19,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1180.2,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 210,
#   'Customer_Satisfaction': 0.7,
#   'CLV': 1425.94,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00020',
#   'Age': 41,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1368.8,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 65,
#   'Customer_Satisfaction': 0.65,
#   'CLV': 316.89,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00021',
#   'Age': 61,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1284.25,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1089,
#   'Customer_Satisfaction': 0.72,
#   'CLV': 11035.12,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00022',
#   'Age': 47,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1487.72,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1450,
#   'Customer_Satisfaction': 0.54,
#   'CLV': 6382.93,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00023',
#   'Age': 55,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1186.3,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 561,
#   'Customer_Satisfaction': 0.58,
#   'CLV': 2115.06,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00024',
#   'Age': 19,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 977.69,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1872,
#   'Customer_Satisfaction': 0.57,
#   'CLV': 11432.71,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00025',
#   'Age': 38,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1251.1,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1283,
#   'Customer_Satisfaction': 0.8,
#   'CLV': 3518.16,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00026',
#   'Age': 50,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1189.25,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1264,
#   'Customer_Satisfaction': 0.83,
#   'CLV': 13673.05,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00027',
#   'Age': 29,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1280.17,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 499,
#   'Customer_Satisfaction': 0.96,
#   'CLV': 1680.14,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00028',
#   'Age': 39,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1299.39,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1837,
#   'Customer_Satisfaction': 0.63,
#   'CLV': 4119.99,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00029',
#   'Age': 61,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1119.82,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1059,
#   'Customer_Satisfaction': 0.7,
#   'CLV': 11371.54,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00030',
#   'Age': 42,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1048.65,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 488,
#   'Customer_Satisfaction': 0.81,
#   'CLV': 3406.93,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00031',
#   'Age': 66,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1178.11,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1447,
#   'Customer_Satisfaction': 0.99,
#   'CLV': 23118.88,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00032',
#   'Age': 44,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 842.82,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 188,
#   'Customer_Satisfaction': 0.7,
#   'CLV': 911.63,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00033',
#   'Age': 59,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1212.1,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1199,
#   'Customer_Satisfaction': 0.64,
#   'CLV': 2548.27,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00034',
#   'Age': 45,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1138.88,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 381,
#   'Customer_Satisfaction': 0.69,
#   'CLV': 4101.37,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00035',
#   'Age': 33,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1329.25,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1734,
#   'Customer_Satisfaction': 0.65,
#   'CLV': 8209.3,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00036',
#   'Age': 32,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 902.12,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 903,
#   'Customer_Satisfaction': 0.54,
#   'CLV': 4820.73,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00037',
#   'Age': 64,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1200.95,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1100,
#   'Customer_Satisfaction': 0.67,
#   'CLV': 9699.73,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00038',
#   'Age': 68,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1436.43,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1589,
#   'Customer_Satisfaction': 0.79,
#   'CLV': 19760.71,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00039',
#   'Age': 61,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1301.31,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 139,
#   'Customer_Satisfaction': 0.59,
#   'CLV': 877.15,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00040',
#   'Age': 69,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1347.1,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1005,
#   'Customer_Satisfaction': 0.92,
#   'CLV': 13649.63,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00041',
#   'Age': 20,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1250.96,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1658,
#   'Customer_Satisfaction': 0.87,
#   'CLV': 14831.18,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00042',
#   'Age': 54,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 950.77,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 516,
#   'Customer_Satisfaction': 0.78,
#   'CLV': 3145.2,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00043',
#   'Age': 68,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1224.98,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 246,
#   'Customer_Satisfaction': 0.87,
#   'CLV': 2154.82,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00044',
#   'Age': 24,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1261.27,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 133,
#   'Customer_Satisfaction': 0.66,
#   'CLV': 606.65,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00045',
#   'Age': 38,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1038.27,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1782,
#   'Customer_Satisfaction': 0.6,
#   'CLV': 3041.42,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00046',
#   'Age': 26,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1181.02,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 709,
#   'Customer_Satisfaction': 0.92,
#   'CLV': 4221.13,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00047',
#   'Age': 56,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 764.84,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1610,
#   'Customer_Satisfaction': 0.91,
#   'CLV': 3070.05,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00048',
#   'Age': 35,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1149.89,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1392,
#   'Customer_Satisfaction': 0.87,
#   'CLV': 7630.48,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00049',
#   'Age': 21,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1134.54,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1767,
#   'Customer_Satisfaction': 0.63,
#   'CLV': 10380.67,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00050',
#   'Age': 42,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1410.34,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1822,
#   'Customer_Satisfaction': 0.67,
#   'CLV': 4716.87,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00051',
#   'Age': 31,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1109.52,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1336,
#   'Customer_Satisfaction': 0.69,
#   'CLV': 11208.77,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00052',
#   'Age': 67,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1160.05,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1587,
#   'Customer_Satisfaction': 0.59,
#   'CLV': 5951.72,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00053',
#   'Age': 26,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1188.12,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1081,
#   'Customer_Satisfaction': 0.88,
#   'CLV': 3096.53,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00054',
#   'Age': 43,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1111.45,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 795,
#   'Customer_Satisfaction': 0.59,
#   'CLV': 5713.16,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00055',
#   'Age': 19,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1307.97,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 973,
#   'Customer_Satisfaction': 0.61,
#   'CLV': 10634.51,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00056',
#   'Age': 37,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 901.14,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1600,
#   'Customer_Satisfaction': 0.52,
#   'CLV': 6162.32,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00057',
#   'Age': 45,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1370.49,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1568,
#   'Customer_Satisfaction': 0.83,
#   'CLV': 9773.21,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00058',
#   'Age': 64,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1198.22,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1475,
#   'Customer_Satisfaction': 0.96,
#   'CLV': 9296.87,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00059',
#   'Age': 24,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1395.25,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1783,
#   'Customer_Satisfaction': 0.74,
#   'CLV': 25218.09,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00060',
#   'Age': 61,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 787.92,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 841,
#   'Customer_Satisfaction': 0.95,
#   'CLV': 1724.68,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00061',
#   'Age': 25,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 834.57,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 534,
#   'Customer_Satisfaction': 0.92,
#   'CLV': 2246.62,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00062',
#   'Age': 64,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1156.2,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1307,
#   'Customer_Satisfaction': 0.9,
#   'CLV': 7452.26,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00063',
#   'Age': 52,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1275.89,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 930,
#   'Customer_Satisfaction': 0.58,
#   'CLV': 3771.04,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00064',
#   'Age': 31,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1116.76,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1293,
#   'Customer_Satisfaction': 0.69,
#   'CLV': 5459.4,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00065',
#   'Age': 34,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1287.58,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 270,
#   'Customer_Satisfaction': 0.83,
#   'CLV': 3952.69,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00066',
#   'Age': 53,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1347.2,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 231,
#   'Customer_Satisfaction': 0.67,
#   'CLV': 1713.75,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00067',
#   'Age': 67,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1299.9,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1188,
#   'Customer_Satisfaction': 0.86,
#   'CLV': 7277.16,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00068',
#   'Age': 57,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1215.49,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1531,
#   'Customer_Satisfaction': 0.64,
#   'CLV': 16314.87,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00069',
#   'Age': 21,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1214.34,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1526,
#   'Customer_Satisfaction': 0.7,
#   'CLV': 14215.43,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00070',
#   'Age': 19,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1107.78,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 455,
#   'Customer_Satisfaction': 0.87,
#   'CLV': 2402.82,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00071',
#   'Age': 23,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1191.69,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 383,
#   'Customer_Satisfaction': 0.56,
#   'CLV': 700.26,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00072',
#   'Age': 59,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1046.37,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 396,
#   'Customer_Satisfaction': 0.89,
#   'CLV': 5051.82,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00073',
#   'Age': 21,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1082.29,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1622,
#   'Customer_Satisfaction': 0.86,
#   'CLV': 4136.19,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00074',
#   'Age': 46,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1277.15,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 114,
#   'Customer_Satisfaction': 0.72,
#   'CLV': 861.6,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00075',
#   'Age': 35,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1130.57,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1210,
#   'Customer_Satisfaction': 0.72,
#   'CLV': 10794.0,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00076',
#   'Age': 43,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1089.37,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 366,
#   'Customer_Satisfaction': 0.95,
#   'CLV': 1037.74,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00077',
#   'Age': 61,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1267.38,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1244,
#   'Customer_Satisfaction': 0.86,
#   'CLV': 7429.56,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00078',
#   'Age': 51,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1256.98,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 961,
#   'Customer_Satisfaction': 0.81,
#   'CLV': 13403.37,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00079',
#   'Age': 27,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1167.71,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 965,
#   'Customer_Satisfaction': 0.93,
#   'CLV': 11484.51,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00080',
#   'Age': 53,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1177.66,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1552,
#   'Customer_Satisfaction': 0.67,
#   'CLV': 16775.04,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00081',
#   'Age': 31,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1262.39,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 50,
#   'Customer_Satisfaction': 0.64,
#   'CLV': 442.7,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00082',
#   'Age': 48,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1345.34,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1663,
#   'Customer_Satisfaction': 0.6,
#   'CLV': 3677.75,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00083',
#   'Age': 65,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1230.16,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1746,
#   'Customer_Satisfaction': 0.76,
#   'CLV': 13416.77,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00084',
#   'Age': 32,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1021.19,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 685,
#   'Customer_Satisfaction': 0.99,
#   'CLV': 9486.58,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00085',
#   'Age': 25,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1166.79,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1739,
#   'Customer_Satisfaction': 0.96,
#   'CLV': 10673.35,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00086',
#   'Age': 31,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1138.93,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 521,
#   'Customer_Satisfaction': 0.73,
#   'CLV': 5933.83,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00087',
#   'Age': 40,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1042.05,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1190,
#   'Customer_Satisfaction': 0.56,
#   'CLV': 5707.58,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00088',
#   'Age': 57,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1274.69,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1289,
#   'Customer_Satisfaction': 0.94,
#   'CLV': 4231.48,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00089',
#   'Age': 38,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1286.23,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1056,
#   'Customer_Satisfaction': 0.96,
#   'CLV': 7144.81,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00090',
#   'Age': 33,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1308.93,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 52,
#   'Customer_Satisfaction': 0.59,
#   'CLV': 220.04,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00091',
#   'Age': 62,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1051.36,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 170,
#   'Customer_Satisfaction': 0.94,
#   'CLV': 460.29,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00092',
#   'Age': 35,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1223.62,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1091,
#   'Customer_Satisfaction': 0.72,
#   'CLV': 13166.82,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00093',
#   'Age': 64,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1199.06,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1215,
#   'Customer_Satisfaction': 0.51,
#   'CLV': 4071.22,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00094',
#   'Age': 41,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1246.11,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 251,
#   'Customer_Satisfaction': 0.97,
#   'CLV': 4156.03,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00095',
#   'Age': 43,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1219.46,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 772,
#   'Customer_Satisfaction': 0.52,
#   'CLV': 6706.03,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00096',
#   'Age': 42,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1198.12,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1463,
#   'Customer_Satisfaction': 0.52,
#   'CLV': 2497.21,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00097',
#   'Age': 62,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1180.09,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1981,
#   'Customer_Satisfaction': 0.98,
#   'CLV': 18830.16,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00098',
#   'Age': 58,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1366.03,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 49,
#   'Customer_Satisfaction': 0.61,
#   'CLV': 335.59,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00099',
#   'Age': 46,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1070.73,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1611,
#   'Customer_Satisfaction': 0.78,
#   'CLV': 18430.93,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00100',
#   'Age': 32,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1174.02,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1155,
#   'Customer_Satisfaction': 0.97,
#   'CLV': 3603.6,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00101',
#   'Age': 62,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1362.21,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1876,
#   'Customer_Satisfaction': 0.97,
#   'CLV': 20374.03,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00102',
#   'Age': 18,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1078.34,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 934,
#   'Customer_Satisfaction': 0.59,
#   'CLV': 8140.14,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00103',
#   'Age': 42,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1085.99,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1540,
#   'Customer_Satisfaction': 0.76,
#   'CLV': 6964.62,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00104',
#   'Age': 24,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1310.09,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1360,
#   'Customer_Satisfaction': 0.5,
#   'CLV': 4881.43,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00105',
#   'Age': 26,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 986.41,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1110,
#   'Customer_Satisfaction': 0.55,
#   'CLV': 6599.49,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00106',
#   'Age': 41,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1299.09,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1901,
#   'Customer_Satisfaction': 0.97,
#   'CLV': 26251.87,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00107',
#   'Age': 18,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1126.55,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1994,
#   'Customer_Satisfaction': 0.71,
#   'CLV': 17478.38,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00108',
#   'Age': 61,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1261.5,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 707,
#   'Customer_Satisfaction': 0.58,
#   'CLV': 4251.7,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00109',
#   'Age': 25,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1016.89,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1889,
#   'Customer_Satisfaction': 0.82,
#   'CLV': 8630.92,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00110',
#   'Age': 41,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1377.76,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1193,
#   'Customer_Satisfaction': 0.59,
#   'CLV': 5313.77,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00111',
#   'Age': 28,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1017.41,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1527,
#   'Customer_Satisfaction': 0.99,
#   'CLV': 12641.5,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00112',
#   'Age': 68,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1308.74,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 146,
#   'Customer_Satisfaction': 0.84,
#   'CLV': 879.47,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00113',
#   'Age': 34,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1023.68,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1191,
#   'Customer_Satisfaction': 0.68,
#   'CLV': 4542.78,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00114',
#   'Age': 25,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1471.25,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 350,
#   'Customer_Satisfaction': 0.69,
#   'CLV': 4867.22,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00115',
#   'Age': 52,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1189.29,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 297,
#   'Customer_Satisfaction': 0.96,
#   'CLV': 1858.03,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00116',
#   'Age': 52,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1492.63,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 465,
#   'Customer_Satisfaction': 0.95,
#   'CLV': 9032.46,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00117',
#   'Age': 50,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1077.17,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 795,
#   'Customer_Satisfaction': 0.97,
#   'CLV': 9103.12,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00118',
#   'Age': 22,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1133.6,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1104,
#   'Customer_Satisfaction': 0.73,
#   'CLV': 2502.99,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00119',
#   'Age': 59,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1381.61,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1011,
#   'Customer_Satisfaction': 0.93,
#   'CLV': 17794.95,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00120',
#   'Age': 56,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 986.07,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 349,
#   'Customer_Satisfaction': 0.74,
#   'CLV': 1395.41,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00121',
#   'Age': 58,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1095.11,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1750,
#   'Customer_Satisfaction': 0.82,
#   'CLV': 17221.73,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00122',
#   'Age': 45,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1274.26,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1658,
#   'Customer_Satisfaction': 0.75,
#   'CLV': 4341.21,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00123',
#   'Age': 24,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1047.18,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1584,
#   'Customer_Satisfaction': 0.8,
#   'CLV': 3635.58,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00124',
#   'Age': 26,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1278.27,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1723,
#   'Customer_Satisfaction': 0.75,
#   'CLV': 18102.4,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00125',
#   'Age': 25,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1225.56,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 761,
#   'Customer_Satisfaction': 0.58,
#   'CLV': 5928.08,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00126',
#   'Age': 29,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 972.95,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1778,
#   'Customer_Satisfaction': 0.55,
#   'CLV': 2606.71,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00127',
#   'Age': 51,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1345.17,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1391,
#   'Customer_Satisfaction': 0.97,
#   'CLV': 4972.6,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00128',
#   'Age': 50,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1010.64,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 774,
#   'Customer_Satisfaction': 0.75,
#   'CLV': 3214.67,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00129',
#   'Age': 65,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1315.69,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 53,
#   'Customer_Satisfaction': 0.97,
#   'CLV': 926.57,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00130',
#   'Age': 40,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1219.27,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1335,
#   'Customer_Satisfaction': 0.84,
#   'CLV': 18729.99,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00131',
#   'Age': 41,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1131.75,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1089,
#   'Customer_Satisfaction': 0.54,
#   'CLV': 1823.39,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00132',
#   'Age': 54,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1034.19,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 904,
#   'Customer_Satisfaction': 0.6,
#   'CLV': 1536.83,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00133',
#   'Age': 52,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1249.39,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 853,
#   'Customer_Satisfaction': 0.88,
#   'CLV': 7708.29,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00134',
#   'Age': 61,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1069.12,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 749,
#   'Customer_Satisfaction': 0.59,
#   'CLV': 1294.4,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00135',
#   'Age': 57,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1381.19,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 855,
#   'Customer_Satisfaction': 0.5,
#   'CLV': 8088.48,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00136',
#   'Age': 39,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1386.67,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1553,
#   'Customer_Satisfaction': 0.56,
#   'CLV': 6608.0,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00137',
#   'Age': 44,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1446.31,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 573,
#   'Customer_Satisfaction': 0.74,
#   'CLV': 5040.53,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00138',
#   'Age': 52,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1242.13,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 287,
#   'Customer_Satisfaction': 0.58,
#   'CLV': 2832.4,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00139',
#   'Age': 18,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1139.35,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1391,
#   'Customer_Satisfaction': 0.52,
#   'CLV': 4515.7,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00140',
#   'Age': 52,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1155.46,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 206,
#   'Customer_Satisfaction': 0.87,
#   'CLV': 1702.04,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00141',
#   'Age': 54,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1144.49,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1550,
#   'Customer_Satisfaction': 0.99,
#   'CLV': 14434.68,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00142',
#   'Age': 64,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1237.2,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1483,
#   'Customer_Satisfaction': 0.99,
#   'CLV': 14929.48,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00143',
#   'Age': 31,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1265.49,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1546,
#   'Customer_Satisfaction': 0.95,
#   'CLV': 15276.37,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00144',
#   'Age': 20,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1384.73,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 624,
#   'Customer_Satisfaction': 0.51,
#   'CLV': 3622.0,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00145',
#   'Age': 18,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1203.02,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 919,
#   'Customer_Satisfaction': 0.62,
#   'CLV': 5633.89,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00146',
#   'Age': 22,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 989.52,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1876,
#   'Customer_Satisfaction': 0.57,
#   'CLV': 11595.76,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00147',
#   'Age': 43,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1138.89,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1795,
#   'Customer_Satisfaction': 0.82,
#   'CLV': 9185.38,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00148',
#   'Age': 31,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1433.38,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 297,
#   'Customer_Satisfaction': 0.92,
#   'CLV': 5365.16,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00149',
#   'Age': 56,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 966.51,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 746,
#   'Customer_Satisfaction': 0.79,
#   'CLV': 1560.56,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00150',
#   'Age': 44,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Persol',
#   'Price': 1310.87,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 476,
#   'Customer_Satisfaction': 0.67,
#   'CLV': 5726.89,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00151',
#   'Age': 26,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1141.41,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 704,
#   'Customer_Satisfaction': 0.96,
#   'CLV': 8453.81,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00152',
#   'Age': 32,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1067.48,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 269,
#   'Customer_Satisfaction': 0.75,
#   'CLV': 2360.15,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00153',
#   'Age': 32,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1259.34,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 146,
#   'Customer_Satisfaction': 0.59,
#   'CLV': 891.61,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00154',
#   'Age': 43,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1434.14,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1639,
#   'Customer_Satisfaction': 0.77,
#   'CLV': 19834.82,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00155',
#   'Age': 59,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1251.07,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1459,
#   'Customer_Satisfaction': 0.51,
#   'CLV': 12752.17,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00156',
#   'Age': 30,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1160.62,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 295,
#   'Customer_Satisfaction': 0.52,
#   'CLV': 1951.11,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00157',
#   'Age': 68,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1005.59,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1359,
#   'Customer_Satisfaction': 0.81,
#   'CLV': 15163.61,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00158',
#   'Age': 49,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1185.17,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1472,
#   'Customer_Satisfaction': 0.86,
#   'CLV': 12331.48,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00159',
#   'Age': 56,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
# ...
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1055.75,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1454,
#   'Customer_Satisfaction': 0.62,
#   'CLV': 2607.5,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00949',
#   'Age': 18,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1238.31,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 235,
#   'Customer_Satisfaction': 0.58,
#   'CLV': 462.42,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00950',
#   'Age': 22,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1311.54,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1781,
#   'Customer_Satisfaction': 0.91,
#   'CLV': 17470.9,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00951',
#   'Age': 58,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1455.65,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 834,
#   'Customer_Satisfaction': 0.53,
#   'CLV': 1762.81,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00952',
#   'Age': 29,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1559.97,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1898,
#   'Customer_Satisfaction': 0.75,
#   'CLV': 30419.42,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00953',
#   'Age': 43,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1297.53,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 47,
#   'Customer_Satisfaction': 0.68,
#   'CLV': 227.23,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00954',
#   'Age': 63,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1254.85,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1892,
#   'Customer_Satisfaction': 0.64,
#   'CLV': 4162.94,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00955',
#   'Age': 51,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1017.4,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1945,
#   'Customer_Satisfaction': 0.88,
#   'CLV': 23854.55,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00956',
#   'Age': 66,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1486.4,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 206,
#   'Customer_Satisfaction': 0.94,
#   'CLV': 3154.26,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00957',
#   'Age': 31,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1232.31,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1704,
#   'Customer_Satisfaction': 0.6,
#   'CLV': 10355.46,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00958',
#   'Age': 43,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1156.64,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 470,
#   'Customer_Satisfaction': 0.54,
#   'CLV': 3217.04,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00959',
#   'Age': 62,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1258.13,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 750,
#   'Customer_Satisfaction': 0.69,
#   'CLV': 5351.36,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00960',
#   'Age': 44,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1104.55,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 560,
#   'Customer_Satisfaction': 0.72,
#   'CLV': 4880.6,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00961',
#   'Age': 26,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 849.35,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1123,
#   'Customer_Satisfaction': 0.53,
#   'CLV': 5540.0,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00962',
#   'Age': 43,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1285.77,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 657,
#   'Customer_Satisfaction': 0.74,
#   'CLV': 3425.29,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00963',
#   'Age': 64,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1401.37,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1007,
#   'Customer_Satisfaction': 0.98,
#   'CLV': 7577.84,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00964',
#   'Age': 39,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1283.54,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 850,
#   'Customer_Satisfaction': 0.69,
#   'CLV': 4124.91,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00965',
#   'Age': 64,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1198.94,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 551,
#   'Customer_Satisfaction': 0.95,
#   'CLV': 6877.65,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00966',
#   'Age': 47,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1201.99,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1310,
#   'Customer_Satisfaction': 0.92,
#   'CLV': 11906.62,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00967',
#   'Age': 60,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1225.84,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1310,
#   'Customer_Satisfaction': 0.72,
#   'CLV': 6335.41,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00968',
#   'Age': 65,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1221.25,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 588,
#   'Customer_Satisfaction': 0.85,
#   'CLV': 5016.83,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00969',
#   'Age': 34,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1190.89,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1283,
#   'Customer_Satisfaction': 0.6,
#   'CLV': 7534.91,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00970',
#   'Age': 43,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1203.8,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 696,
#   'Customer_Satisfaction': 0.57,
#   'CLV': 1308.42,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00971',
#   'Age': 53,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1433.25,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 694,
#   'Customer_Satisfaction': 0.5,
#   'CLV': 6812.85,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00972',
#   'Age': 18,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1270.84,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1271,
#   'Customer_Satisfaction': 0.54,
#   'CLV': 9558.67,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00973',
#   'Age': 25,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1215.77,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 644,
#   'Customer_Satisfaction': 0.81,
#   'CLV': 8687.59,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00974',
#   'Age': 66,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1298.88,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 935,
#   'Customer_Satisfaction': 0.94,
#   'CLV': 12510.53,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00975',
#   'Age': 52,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1298.89,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1217,
#   'Customer_Satisfaction': 0.99,
#   'CLV': 12862.53,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00976',
#   'Age': 69,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1341.9,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1995,
#   'Customer_Satisfaction': 0.74,
#   'CLV': 27137.63,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00977',
#   'Age': 32,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1086.46,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 421,
#   'Customer_Satisfaction': 0.57,
#   'CLV': 714.3,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00978',
#   'Age': 64,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1127.92,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1022,
#   'Customer_Satisfaction': 0.5,
#   'CLV': 7895.44,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00979',
#   'Age': 39,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1077.97,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 987,
#   'Customer_Satisfaction': 0.99,
#   'CLV': 14429.0,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00980',
#   'Age': 31,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1315.01,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 954,
#   'Customer_Satisfaction': 0.91,
#   'CLV': 3127.71,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00981',
#   'Age': 43,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1307.68,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 82,
#   'Customer_Satisfaction': 0.76,
#   'CLV': 223.27,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00982',
#   'Age': 45,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1009.01,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1023,
#   'Customer_Satisfaction': 0.62,
#   'CLV': 3506.71,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00983',
#   'Age': 40,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1258.63,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1528,
#   'Customer_Satisfaction': 0.76,
#   'CLV': 16017.77,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00984',
#   'Age': 31,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1405.84,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 903,
#   'Customer_Satisfaction': 0.92,
#   'CLV': 9599.31,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00985',
#   'Age': 41,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1164.7,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 33,
#   'Customer_Satisfaction': 0.78,
#   'CLV': 410.68,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00986',
#   'Age': 19,
#   'Gender': 'Female',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1247.1,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1614,
#   'Customer_Satisfaction': 1.0,
#   'CLV': 27572.87,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00987',
#   'Age': 62,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1309.57,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1677,
#   'Customer_Satisfaction': 0.55,
#   'CLV': 9927.8,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00988',
#   'Age': 43,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Vogue Eyewear',
#   'Price': 1001.92,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 1250,
#   'Customer_Satisfaction': 0.99,
#   'CLV': 3396.92,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00989',
#   'Age': 31,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1222.8,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 711,
#   'Customer_Satisfaction': 0.79,
#   'CLV': 1881.74,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00990',
#   'Age': 68,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1390.82,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 659,
#   'Customer_Satisfaction': 0.78,
#   'CLV': 9793.28,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00991',
#   'Age': 24,
#   'Gender': 'Male',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1111.02,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1128,
#   'Customer_Satisfaction': 0.68,
#   'CLV': 11673.93,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00992',
#   'Age': 20,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1324.87,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 1886,
#   'Customer_Satisfaction': 0.52,
#   'CLV': 10679.4,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00993',
#   'Age': 64,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oakley',
#   'Price': 1204.07,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 234,
#   'Customer_Satisfaction': 0.88,
#   'CLV': 2037.88,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00994',
#   'Age': 40,
#   'Gender': 'Male',
#   'Income_Level': 'High',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1098.82,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1649,
#   'Customer_Satisfaction': 0.64,
#   'CLV': 12708.5,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST00995',
#   'Age': 63,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Persol',
#   'Price': 1185.52,
#   'Purchase_Frequency': 1,
#   'Customer_Tenure_Days': 575,
#   'Customer_Satisfaction': 0.68,
#   'CLV': 1269.97,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00996',
#   'Age': 60,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oakley',
#   'Price': 1121.08,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 1406,
#   'Customer_Satisfaction': 0.77,
#   'CLV': 6650.43,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00997',
#   'Age': 64,
#   'Gender': 'Female',
#   'Income_Level': 'Low',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1066.75,
#   'Purchase_Frequency': 2,
#   'Customer_Tenure_Days': 555,
#   'Customer_Satisfaction': 0.53,
#   'CLV': 1719.37,
#   'CLV_Class': 'Low'},
#  {'CustomerID': 'CUST00998',
#   'Age': 62,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Ray-Ban',
#   'Price': 1161.85,
#   'Purchase_Frequency': 3,
#   'Customer_Tenure_Days': 978,
#   'Customer_Satisfaction': 0.51,
#   'CLV': 4763.08,
#   'CLV_Class': 'Medium'},
#  {'CustomerID': 'CUST00999',
#   'Age': 35,
#   'Gender': 'Female',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Optical Glasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1210.26,
#   'Purchase_Frequency': 4,
#   'Customer_Tenure_Days': 1385,
#   'Customer_Satisfaction': 0.55,
#   'CLV': 10103.18,
#   'CLV_Class': 'High'},
#  {'CustomerID': 'CUST01000',
#   'Age': 55,
#   'Gender': 'Male',
#   'Income_Level': 'Medium',
#   'Eyewear_Type': 'Sunglasses',
#   'Brand': 'Oliver Peoples',
#   'Price': 1175.09,
#   'Purchase_Frequency': 5,
#   'Customer_Tenure_Days': 1256,
#   'Customer_Satisfaction': 0.87,
#   'CLV': 17589.65,
#   'CLV_Class': 'High'},
#  ...]

# %%
DB_NAME = "clv1"
COLLECTION_NAME = "clv_data"
CONNECTION_URL = "mongodb+srv://jash142:jash142@cluster0.i2lugmj.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")

# %%
import pandas as pd
df = pd.DataFrame(list(collection.find()))

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
